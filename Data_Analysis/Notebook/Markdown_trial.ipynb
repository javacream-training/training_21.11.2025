# %% [markdown]
# # Title

# %% [markdown]
# ## Label

# %% [markdown]
# * point
#   * sub 1
#   * sub 2

# %% [markdown]
# - main
#    1. 1st item **bold**
#    2. 2nd item *italic*
#    3. 3rd item ~~strikethrough~~
