# %% [markdown]
# # Analyse des Personen-Datensatzes
#
# ## Datensatz
#
# * PEOPLE.csv
# * Abzug aus der Unternehmens-Datenbank

# %% [markdown]
# ## Analyse
#
# ### Einlesen der Daten

# %%
import csv
with open('people_data.csv', encoding='people_data.csv') as file:
    pass

# %% [markdown]
# ## Was für Spalten haben wir? Was sind die Datentypen?

# %%
print(data.keys())

# %% [markdown]
# ## Was ist das maximale Körpergewicht? Wer hat dieses Gewicht?

# %%
max(data['height'])

# %% [markdown]
# ## Welche Personen mit einem Gewicht kleiner 75kg haben einen Nachnamen, der mit "S" beginnt?
